# %% [markdown]
# # Qualite nutritionnelle_final

# %%
# Import de la librairie Pandas
import pandas as pd

# Import de la librairie matplotlib
import matplotlib.pyplot as plt

# %% [markdown]
# ### 1.1 - Chargement des données

# %%
dtype_options = {'code': str}
qualite = pd.read_csv("Qualite_nutritionnelle_final.csv", sep ="\t", dtype=dtype_options)
qualite.head(5
            )
# Out:
#                    code                  product_name quantity    brands_tags  \
# 0  00000000000026772226                          Skyr    480 g         danone
# 1         0000000000017              Vitória crackers      NaN            NaN
# 2         0000000000031                         Cacao    130 g            NaN
# 3         0000000000100   moutarde au moût de raisin      100g  courte-paille
# 4         0000000000123         Sauce Sweety chili 0%      NaN            NaN
#
#   countries_tags serving_size  \
# 0      en:france          NaN
# 1      en:france          NaN
# 2      en:france          NaN
# 3      en:france          NaN
# 4      en:france          NaN
#
#                                            image_url  \
# 0  https://images.openfoodfacts.org/images/produc...
# 1  https://images.openfoodfacts.org/images/produc...
# 2  https://images.openfoodfacts.org/images/produc...
# 3  https://images.openfoodfacts.org/images/produc...
# ...

# %%
qualite.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 932866 entries, 0 to 932865
# Data columns (total 16 columns):
#  #   Column              Non-Null Count   Dtype
# ---  ------              --------------   -----
#  0   code                932866 non-null  object
#  1   product_name        907007 non-null  object
#  2   quantity            279260 non-null  object
#  3   brands_tags         463922 non-null  object
#  4   countries_tags      932866 non-null  object
#  5   serving_size        89842 non-null   object
#  6   image_url           842701 non-null  object
#  7   ingredients_tags    259155 non-null  object
#  8   nutriscore_grade    319615 non-null  object
#  9   energy-kcal_100g    686843 non-null  float64
#  10  fat_100g            703194 non-null  float64
#  11  saturated-fat_100g  708835 non-null  float64
#  12  sugars_100g         708136 non-null  float64
#  13  proteins_100g       705019 non-null  float64
#  14  salt_100g           676852 non-null  float64
# ...

# %%
qualite.duplicated().sum()
# Out:
# 89623

# %%
qualite = qualite.drop_duplicates()

# %%
qualite_without_nan = qualite.dropna()
qualite_without_nan
# Out:
#                  code                         product_name           quantity  \
# 136     0000007020254                            Root Beer            33 cl e
# 143     0000009125124                     Compote de Pomme               40 g
# 239     0000040144078                  M&M's Peanut Butter             46.2 g
# 247     0000050157846     Heinz Squeeze Sauce Salade Cream              425 g
# 271     0000069028045  Lasagnes aux saumon et aux épinards              500 g
# ...               ...                                  ...                ...
# 925605  8801052801773               Hot Pepper Beans Paste            200.0 g
# 927134  8888003250309               Tyj Spring Roll Pastry  30 sheets (550 g)
# 928587  9002515601452                Pago nectarine citron            0.75L e
# 929327       90435973                 Redbull Wassermelone             250 ml
# 930854  9415912000207         The original chocolate chunk               250g
#
# ...

# %%
qualite_without_nan.describe()
# Out:
#        energy-kcal_100g      fat_100g  saturated-fat_100g   sugars_100g  \
# count      49948.000000  4.994800e+04        49948.000000  49948.000000
# mean         267.519949  1.761832e+08            5.013898     12.502281
# std          268.233901  3.937527e+10            7.546803     17.026213
# min            0.000000  0.000000e+00            0.000000      0.000000
# 25%          104.000000  1.700000e+00            0.400000      1.300000
# 50%          246.000000  7.400000e+00            2.100000      4.500000
# 75%          404.000000  2.000000e+01            6.900000     18.000000
# max        40000.000000  8.799999e+12          400.000000    800.000000
#
#        proteins_100g     salt_100g      nb_nocif
# count   49948.000000  49948.000000  49948.000000
# mean        7.619531      0.879204      0.001401
# std         7.777288      2.393890      0.037410
# min         0.000000      0.000000      0.000000
# 25%         2.600000      0.100000      0.000000
# ...
